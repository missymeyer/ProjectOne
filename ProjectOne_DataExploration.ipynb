# %% [markdown]
# # Project One - Data Exploration

# %%
# Dependencies
import pandas as pd
import requests
import json
import os
import datetime
import matplotlib.pyplot as plt
import numpy as np

# Google API Key
from config import gkey

# %%
# Source files
attendance_raw = 'Resources/Raw/National_Park_Attendance_Prev3Y.xlsx'
park_info = 'Resources/Raw/National_Park_Locations.xlsx'
state_orders = 'Resources/Raw/state_orders.xlsx'
wildfires = '/Users/laurelwilliamson/Desktop/GITHUB/group_project/ProjectOne/Resources/Wildfire_Perimeters (1).csv'
more_park_info = '/Users/laurelwilliamson/Desktop/GITHUB/group_project/ProjectOne/Resources/Raw/data.json'

# Read data and store in dataframe
attendance_data = pd.read_excel(attendance_raw)
park_info_data = pd.read_excel(park_info)
emergency_orders_data = pd.read_excel(state_orders)
wildfire_data = pd.read_csv(wildfires)
more_park_data = pd.read_json(more_park_info)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-92d1c1ffab49> in <module>
#      10 park_info_data = pd.read_excel(park_info)
#      11 emergency_orders_data = pd.read_excel(state_orders)
# ---> 12 wildfire_data = pd.read_csv(wildfires)
#      13 more_park_data = pd.read_json(more_park_info)
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File /Users/laurelwilliamson/Desktop/GITHUB/group_project/ProjectOne/Resources/Wildfire_Perimeters (1).csv does not exist: '/Users/laurelwilliamson/Desktop/GITHUB/group_project/ProjectOne/Resources/Wildfire_Perimeters (1).csv'

# %% [markdown]
# ## Import, filter, and clean base park data

# %%
# Limit park info dataframe to West Coast
national_parks = park_info_data.loc[(park_info_data['ParkType']=='National Park')]
focus_parks = pd.DataFrame(national_parks.loc[(park_info_data['State'] == 'CA') | (park_info_data['State'] == 'OR') | (park_info_data['State'] == 'WA')])
focus_parks.reset_index()

focus_parks['FullName'] = focus_parks['Park'].str.replace(['NP'],'')#+focus_parks['ParkType'])

focus_parks['FullName']=focus_parks['Park'].str[:-2]+focus_parks['ParkType']

focus_parks.head()
# Out:
#                    Park UnitCode       ParkType         Region State  \
# 63   Channel Islands NP     CHIS  National Park  Pacific West     CA
# 79       Crater Lake NP     CRLA  National Park  Pacific West     OR
# 87      Death Valley NP     DEVA  National Park  Pacific West     CA
# 191      Joshua Tree NP     JOTR  National Park  Pacific West     CA
# 198     Kings Canyon NP     KICA  National Park  Pacific West     CA
#
#                           FullName
# 63   Channel Islands National Park
# 79       Crater Lake National Park
# 87      Death Valley National Park
# 191      Joshua Tree National Park
# 198     Kings Canyon National Park

# %% [markdown]
# ## Bring in geocoordinates via Google Maps API

# %%
# Build URL using the Google Maps API

lats=[]
longs=[]
cost=[]

base_url = "https://maps.googleapis.com/maps/api/geocode/json"

for Park in focus_parks['FullName']:
    params = {"address": Park, "key": gkey}
    response = requests.get(base_url, params=params)
    park_geo = response.json()
    lats.append(park_geo["results"][0]["geometry"]["location"]["lat"])
    longs.append(park_geo["results"][0]["geometry"]["location"]["lng"])

# %%
# Add geocoordinates to dataframe
focus_parks['Latitude']=lats
focus_parks['Longitude']=longs
focus_parks.head()
# Out:
#                    Park UnitCode       ParkType         Region State  \
# 63   Channel Islands NP     CHIS  National Park  Pacific West     CA
# 79       Crater Lake NP     CRLA  National Park  Pacific West     OR
# 87      Death Valley NP     DEVA  National Park  Pacific West     CA
# 191      Joshua Tree NP     JOTR  National Park  Pacific West     CA
# 198     Kings Canyon NP     KICA  National Park  Pacific West     CA
#
#                           FullName   Latitude   Longitude
# 63   Channel Islands National Park  34.006936 -119.778533
# 79       Crater Lake National Park  42.868441 -122.168479
# 87      Death Valley National Park  36.505389 -117.079408
# 191      Joshua Tree National Park  33.873415 -115.900992
# 198     Kings Canyon National Park  36.887855 -118.555148

# %%
# Create 'clean' Excel file with focus park geocoordiantes
focus_parks.to_excel('Resources/Clean/Clean_ParkGeocoordinates.xlsx',
             sheet_name='Park Geocoordinates')

# %% [markdown]
# ## Combine base park data, visitor counts, and geocoordinate data

# %%
# Combine the data into a single dataframe  
park_data = pd.merge(focus_parks, attendance_data, how="left", on=["Park", "Park"])
park_data.head()
# Out:
#                  Park UnitCode       ParkType         Region State  \
# 0  Channel Islands NP     CHIS  National Park  Pacific West     CA
# 1  Channel Islands NP     CHIS  National Park  Pacific West     CA
# 2  Channel Islands NP     CHIS  National Park  Pacific West     CA
# 3  Channel Islands NP     CHIS  National Park  Pacific West     CA
# 4  Channel Islands NP     CHIS  National Park  Pacific West     CA
#
#                         FullName   Latitude   Longitude  Code      Month  \
# 0  Channel Islands National Park  34.006936 -119.778533  CHIS 2020-01-01
# 1  Channel Islands National Park  34.006936 -119.778533  CHIS 2020-02-01
# 2  Channel Islands National Park  34.006936 -119.778533  CHIS 2020-03-01
# 3  Channel Islands National Park  34.006936 -119.778533  CHIS 2020-04-01
# 4  Channel Islands National Park  34.006936 -119.778533  CHIS 2020-05-01
#
#    Visitors
# 0   19555.0
# 1   19682.0
# 2    9913.0
# 3     113.0
# 4    1618.0

# %%
park_data['Calendar Year'] = pd.DatetimeIndex(park_data['Month']).year
park_data['Calendar Month'] = pd.DatetimeIndex(park_data['Month']).month

park_data = park_data.set_index('FullName')

park_data.head(50)
# Out:
#                                              Park UnitCode       ParkType  \
# FullName
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Channel Islands National Park  Channel Islands NP     CHIS  National Park
# Crater Lake National Park          Crater Lake NP     CRLA  National Park
# Crater Lake National Park          Crater Lake NP     CRLA  National Park
# Crater Lake National Park          Crater Lake NP     CRLA  National Park
#
#                                       Region State   Latitude   Longitude  \
# FullName
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Channel Islands National Park  Pacific West     CA  34.006936 -119.778533
# Crater Lake National Park      Pacific West     OR  42.868441 -122.168479
# Crater Lake National Park      Pacific West     OR  42.868441 -122.168479
# Crater Lake National Park      Pacific West     OR  42.868441 -122.168479
#
#                                Code      Month  Visitors  Calendar Year  \
# FullName
# Channel Islands National Park  CHIS 2020-01-01   19555.0           2020
# Channel Islands National Park  CHIS 2020-02-01   19682.0           2020
# Channel Islands National Park  CHIS 2020-03-01    9913.0           2020
# Channel Islands National Park  CHIS 2020-04-01     113.0           2020
# Channel Islands National Park  CHIS 2020-05-01    1618.0           2020
# Channel Islands National Park  CHIS 2020-06-01    7088.0           2020
# Channel Islands National Park  CHIS 2020-07-01    9999.0           2020
# Channel Islands National Park  CHIS 2020-08-01   11694.0           2020
# Channel Islands National Park  CHIS 2020-09-01    8487.0           2020
# Channel Islands National Park  CHIS 2020-10-01   26302.0           2020
# Channel Islands National Park  CHIS 2020-11-01   17744.0           2020
# Channel Islands National Park  CHIS 2017-01-01   18887.0           2017
# Channel Islands National Park  CHIS 2017-02-01   20325.0           2017
# Channel Islands National Park  CHIS 2017-03-01   32263.0           2017
# Channel Islands National Park  CHIS 2017-04-01   33888.0           2017
# Channel Islands National Park  CHIS 2017-05-01   37528.0           2017
# Channel Islands National Park  CHIS 2017-06-01   44852.0           2017
# Channel Islands National Park  CHIS 2017-07-01   56194.0           2017
# Channel Islands National Park  CHIS 2017-08-01   40750.0           2017
# Channel Islands National Park  CHIS 2017-09-01   33063.0           2017
# Channel Islands National Park  CHIS 2017-10-01   25495.0           2017
# Channel Islands National Park  CHIS 2017-11-01   23696.0           2017
# Channel Islands National Park  CHIS 2017-12-01   16746.0           2017
# Channel Islands National Park  CHIS 2018-01-01   15986.0           2018
# Channel Islands National Park  CHIS 2018-02-01   24878.0           2018
# Channel Islands National Park  CHIS 2018-03-01   30668.0           2018
# Channel Islands National Park  CHIS 2018-04-01   37565.0           2018
# Channel Islands National Park  CHIS 2018-05-01   33616.0           2018
# Channel Islands National Park  CHIS 2018-06-01   39141.0           2018
# Channel Islands National Park  CHIS 2018-07-01   49533.0           2018
# Channel Islands National Park  CHIS 2018-08-01   39684.0           2018
# Channel Islands National Park  CHIS 2018-09-01   31267.0           2018
# Channel Islands National Park  CHIS 2018-10-01   26844.0           2018
# Channel Islands National Park  CHIS 2018-11-01   21703.0           2018
# Channel Islands National Park  CHIS 2018-12-01   15365.0           2018
# Channel Islands National Park  CHIS 2019-01-01    9193.0           2019
# Channel Islands National Park  CHIS 2019-02-01   22263.0           2019
# Channel Islands National Park  CHIS 2019-03-01   34951.0           2019
# Channel Islands National Park  CHIS 2019-04-01   39218.0           2019
# Channel Islands National Park  CHIS 2019-05-01   39070.0           2019
# Channel Islands National Park  CHIS 2019-06-01   44915.0           2019
# Channel Islands National Park  CHIS 2019-07-01   47581.0           2019
# Channel Islands National Park  CHIS 2019-08-01   49793.0           2019
# Channel Islands National Park  CHIS 2019-09-01   38681.0           2019
# Channel Islands National Park  CHIS 2019-10-01   36691.0           2019
# Channel Islands National Park  CHIS 2019-11-01   25212.0           2019
# Channel Islands National Park  CHIS 2019-12-01   22062.0           2019
# Crater Lake National Park      CRLA 2020-01-01    3492.0           2020
# Crater Lake National Park      CRLA 2020-02-01    3351.0           2020
# Crater Lake National Park      CRLA 2020-03-01    5304.0           2020
#
#                                Calendar Month
# FullName
# Channel Islands National Park               1
# Channel Islands National Park               2
# Channel Islands National Park               3
# Channel Islands National Park               4
# Channel Islands National Park               5
# Channel Islands National Park               6
# Channel Islands National Park               7
# Channel Islands National Park               8
# Channel Islands National Park               9
# Channel Islands National Park              10
# Channel Islands National Park              11
# Channel Islands National Park               1
# Channel Islands National Park               2
# Channel Islands National Park               3
# Channel Islands National Park               4
# Channel Islands National Park               5
# Channel Islands National Park               6
# Channel Islands National Park               7
# Channel Islands National Park               8
# Channel Islands National Park               9
# Channel Islands National Park              10
# Channel Islands National Park              11
# Channel Islands National Park              12
# Channel Islands National Park               1
# Channel Islands National Park               2
# Channel Islands National Park               3
# Channel Islands National Park               4
# Channel Islands National Park               5
# Channel Islands National Park               6
# Channel Islands National Park               7
# Channel Islands National Park               8
# Channel Islands National Park               9
# Channel Islands National Park              10
# Channel Islands National Park              11
# Channel Islands National Park              12
# Channel Islands National Park               1
# Channel Islands National Park               2
# Channel Islands National Park               3
# Channel Islands National Park               4
# Channel Islands National Park               5
# Channel Islands National Park               6
# Channel Islands National Park               7
# Channel Islands National Park               8
# Channel Islands National Park               9
# Channel Islands National Park              10
# Channel Islands National Park              11
# Channel Islands National Park              12
# Crater Lake National Park                   1
# Crater Lake National Park                   2
# Crater Lake National Park                   3

# %%
# Create 'clean' Excel file with pertinent park data
park_data.to_excel('Resources/Clean/Clean_ParkData.xlsx',
             sheet_name='Park Data')

# %%
# Generate a bar plot for visitors by month 
argh_group = park_data.groupby('Month')
measures = pd.DataFrame(argh_group['Visitors'].sum())

drug_chart=measures.plot(kind='bar', title='National Park Visitors', color='navy')

drug_chart.set_xlabel('Month')
drug_chart.set_ylabel('Total Visitors')

plt.show()

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the visutors for each calendar year
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 


mean = park_data.groupby('Calendar Year').mean()['Visitors']
median = park_data.groupby('Calendar Year').median()['Visitors']
variance = park_data.groupby('Calendar Year').var()['Visitors']
std_dev = park_data.groupby('Calendar Year').std()['Visitors']
SEM = park_data.groupby('Calendar Year').sem()['Visitors']

# Assemble the resulting series into a single summary dataframe.
park_stats = pd.DataFrame({'Mean': mean,
              'Median':median,
              'Variance': variance,
              'Standard Deviation': std_dev,
                         'SEM':SEM})
park_stats.head(12)
# Out:
#                         Mean   Median      Variance  Standard Deviation  \
# Calendar Year
# 2017           112812.429487  58283.5  2.080075e+10       144224.659279
# 2018           112199.730769  61345.5  1.682381e+10       129706.619776
# 2019           116213.320513  61149.0  2.174953e+10       147477.208613
# 2020            77289.272727  24128.0  1.320128e+10       114896.815200
#
#                         SEM
# Calendar Year
# 2017           11547.214212
# 2018           10384.840781
# 2019           11807.626572
# 2020            9608.154369

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Using the aggregation method, produce the same summary statistics in a single line
# Google take the wheel ...
summary_stats= park_data.groupby('Park').agg({'Visitors':['mean','median','var','std','sem']})
summary_stats
# Out:
#                          Visitors                                         \
#                              mean    median           var            std
# Park
# Channel Islands NP   27484.297872   26302.0  1.832456e+08   13536.825577
# Crater Lake NP       59177.021277   21309.0  4.604204e+09   67854.283004
# Death Valley NP     115497.978723  122013.0  1.951054e+09   44170.739525
# Joshua Tree NP      232243.617021  233995.0  8.984922e+09   94788.830975
# Kings Canyon NP      51721.340426   40030.0  1.436163e+09   37896.743394
# Lassen Volcanic NP   41899.361702   12879.0  1.754974e+09   41892.415390
# Mount Rainier NP    117973.361702   74355.0  1.399575e+10  118303.654303
# North Cascades NP     2755.297872     198.0  1.681849e+07    4101.035579
# Olympic NP          257574.468085  182944.0  4.387051e+10  209452.883860
# Pinnacles NP         16544.914894   15829.0  4.572308e+07    6761.884388
# Redwood NP           35815.212766   30938.0  3.509364e+08   18733.297810
# Sequoia NP           96466.787234   83442.0  3.839955e+09   61967.369821
# Yosemite NP         312581.255319  278349.0  3.944555e+10  198609.036258
#
#
#                              sem
# Park
# Channel Islands NP   1974.548948
# Crater Lake NP       9897.564413
# Death Valley NP      6442.964545
# Joshua Tree NP      13826.372024
# Kings Canyon NP      5527.808153
# Lassen Volcanic NP   6110.636815
# Mount Rainier NP    17256.361529
# North Cascades NP     598.197520
# Olympic NP          30551.843123
# Pinnacles NP          986.322209
# Redwood NP           2732.532326
# Sequoia NP           9038.869872
# Yosemite NP         28970.105385

# %%
# Split up our data into groups based upon 'Calendar Year' and 'Calendar Month'
year_groups = park_data.groupby(['Calendar Year','Calendar Month'])

# Create a new variable that holds the sum of our groups
monthly_summary = year_groups.sum()
monthly_summary.head(50)
# Out:
#                                 Latitude    Longitude   Visitors
# Calendar Year Calendar Month
# 2017          1               520.148799 -1564.824142   662187.0
#               2               520.148799 -1564.824142   671480.0
#               3               520.148799 -1564.824142   992657.0
#               4               520.148799 -1564.824142  1266715.0
#               5               520.148799 -1564.824142  1637021.0
#               6               520.148799 -1564.824142  2061602.0
#               7               520.148799 -1564.824142  2585434.0
#               8               520.148799 -1564.824142  2707533.0
#               9               520.148799 -1564.824142  1970603.0
#               10              520.148799 -1564.824142  1346373.0
#               11              520.148799 -1564.824142   936351.0
#               12              520.148799 -1564.824142   760783.0
# 2018          1               520.148799 -1564.824142   789501.0
#               2               520.148799 -1564.824142   808170.0
#               3               520.148799 -1564.824142  1064691.0
#               4               520.148799 -1564.824142  1195308.0
#               5               520.148799 -1564.824142  1608871.0
#               6               520.148799 -1564.824142  2065430.0
#               7               520.148799 -1564.824142  2374889.0
#               8               520.148799 -1564.824142  2393532.0
#               9               520.148799 -1564.824142  1871944.0
#               10              520.148799 -1564.824142  1379187.0
#               11              520.148799 -1564.824142   993563.0
#               12              520.148799 -1564.824142   958072.0
# 2019          1               520.148799 -1564.824142   605921.0
#               2               520.148799 -1564.824142   670046.0
#               3               520.148799 -1564.824142  1155917.0
#               4               520.148799 -1564.824142  1290567.0
#               5               520.148799 -1564.824142  1582516.0
#               6               520.148799 -1564.824142  2081930.0
#               7               520.148799 -1564.824142  2624976.0
#               8               520.148799 -1564.824142  2805117.0
#               9               520.148799 -1564.824142  2014533.0
#               10              520.148799 -1564.824142  1474949.0
#               11              520.148799 -1564.824142   989485.0
#               12              520.148799 -1564.824142   833321.0
# 2020          1               520.148799 -1564.824142   732397.0
#               2               520.148799 -1564.824142   819186.0
#               3               520.148799 -1564.824142   550521.0
#               4               520.148799 -1564.824142    66384.0
#               5               520.148799 -1564.824142   150094.0
#               6               520.148799 -1564.824142  1046707.0
#               7               520.148799 -1564.824142  2185952.0
#               8               520.148799 -1564.824142  2309622.0
#               9               520.148799 -1564.824142  1065666.0
#               10              520.148799 -1564.824142  1091669.0
#               11              520.148799 -1564.824142  1034168.0

# %%
# Create 'clean' Excel file with summary of vistors by month year-over-year
monthly_summary.to_excel('Resources/Clean/Clean_YOY_MonthlyVisitors.xlsx',
             sheet_name='Year-Over-Year Visitors Summary')

# %% [markdown]
# ## Wildfire Data

# %%
#Preview
wildfire_data.head()
# Out:
#    OBJECTID    IncidentName                FeatureCategory  \
# 0     86547  Bradbury Krebs  Wildfire Daily Fire Perimeter
# 1     89869      Cottonwood  Wildfire Daily Fire Perimeter
# 2     89870        FLAT TOP  Wildfire Daily Fire Perimeter
# 3     89877         Lincoln  Wildfire Daily Fire Perimeter
# 4     89882  Moore Mountain  Wildfire Daily Fire Perimeter
#
#                 MapMethod                                           Comments  \
# 0  Remote Sensing Derived                                                NaN
# 1           Mixed Methods                                                NaN
# 2              GPS-Flight  Utilization of drone to aerial map fire perime...
# 3           Mixed Methods                                                NaN
# 4         Digitized-Image                                                NaN
#
#      GISAcres            Label FeatureAccess FeatureStatus IsVisible  ...  \
# 0   96.387621              NaN        Public      Approved       Yes  ...
# 1    5.981838              NaN        Public      Approved       Yes  ...
# 2  374.443632              NaN        Public      Approved       Yes  ...
# 3   43.376002              NaN        Public      Approved       Yes  ...
# 4   11.501785  Moore Mtn, 2020        Public      Approved       Yes  ...
#
#    GACC IMTName UnitID LocalIncidentID  \
# 0  RMCC     NaN    NaN             NaN
# 1  GBCC     NaN  IDTFD          000073
# 2  RMCC     NaN  WYCOX          200144
# 3  GBCC     NaN  UTSLD          000296
# 4  SACC     NaN  VAVAS       Moore Mtn
#
#                                   IRWINID GeometryID  \
# 0                                     NaN        NaN
# 1  {B3FAE568-6B2E-43CB-9767-7273D7C29B28}        NaN
# 2  {6EBEA127-231D-4EE1-8A6A-39F034B1752C}        NaN
# 3  {83840CC1-B9E8-4E8F-B1B5-353E02A08A73}        NaN
# 4  {9BC142C4-6A28-4EF6-B683-438DCDF13706}        NaN
#
#                                GlobalID  \
# 0  016394ae-ee1b-4a97-bbb8-eac4cb650178
# 1  2031a057-2e4d-45ff-9bf7-950250c590a8
# 2  d6fb873a-01ea-495c-829b-d3d89c14d3cc
# 3  a6f5723b-f060-4083-996c-1c3ae14ded37
# 4  db4cfe17-fe55-437e-b767-023a6b6af3a0
#
#                                GlobalID_2 SHAPE_Length SHAPE_Area
# 0  {1BE763D8-687D-44DB-A01A-43E1DE6E219A}     0.026316   0.000041
# 1  {8B4D7AEC-226E-4043-8AF9-F1F9DFE470E4}     0.008370   0.000003
# 2  {1D7EE141-27D5-4F66-9311-C217A15BA0AA}     0.072647   0.000167
# 3  {019C0D34-B99B-4CCE-A479-6D402D23F969}     0.023222   0.000019
# 4  {298BEC61-E2CC-4532-96DE-21A60A0A2B22}     0.011176   0.000005
#
# [5 rows x 25 columns]

# %%
#Eliminate unneccessary columns
wildfires_df = wildfire_data[['IncidentName', 'CreateDate']].copy()
wildfires_df.head()

#Export as CSV
fires_df.to_csv(r'/Users/laurelwilliamson/Desktop/GITHUB/group_project/ProjectOne/Resources/2020wildfires.csv', index = False)
# Out:
#      IncidentName           CreateDate
# 0  Bradbury Krebs  2020/07/01 22:37:53
# 1      Cottonwood  2020/07/10 20:22:46
# 2        FLAT TOP  2020/07/10 20:24:01
# 3         Lincoln  2020/06/19 21:54:43
# 4  Moore Mountain  2020/07/10 20:21:31

# %% [markdown]
# ## State Emergency Orders Related to COVID

# %%
# Limit emergency order dataframe to West Coast
all_orders = pd.DataFrame(emergency_orders_data.loc[(emergency_orders_data['policy_level'] == 'state') & (emergency_orders_data['start_stop'] == 'start')])
emergency_orders = pd.DataFrame(all_orders.loc[(all_orders['policy_type'] == 'Entertainment') | (all_orders['policy_type'] == 'Food and Drink') | (all_orders['policy_type'] == 'Gyms') | (all_orders['policy_type'] == 'Non-Essential Businesses')])
state_restrictions = pd.DataFrame(emergency_orders.loc[(emergency_orders['state_id'] == 'CA') | (emergency_orders['state_id'] == 'OR') | (emergency_orders['state_id'] == 'WA')])
state_restrictions.reset_index()

state_restrictions.head(20)
# Out:
#      state_id county  fips_code policy_level       date  \
# 501        CA    NaN        NaN        state 2020-05-08
# 628        OR    NaN        NaN        state 2020-05-15
# 768        OR    NaN        NaN        state 2020-05-15
# 1198       CA    NaN        NaN        state 2020-03-19
# 1453       WA    NaN        NaN        state 2020-05-05
# 1660       OR    NaN        NaN        state 2020-05-15
# 1678       WA    NaN        NaN        state 2020-03-16
# 1942       OR    NaN        NaN        state 2020-05-15
# 1943       OR    NaN        NaN        state 2020-05-15
# 1969       WA    NaN        NaN        state 2020-05-05
# 2426       CA    NaN        NaN        state 2020-03-19
# 2441       WA    NaN        NaN        state 2020-05-05
# 3125       CA    NaN        NaN        state 2020-05-08
# 3339       OR    NaN        NaN        state 2020-03-24
#
#                    policy_type start_stop  \
# 501              Entertainment      start
# 628   Non-Essential Businesses      start
# 768             Food and Drink      start
# 1198                      Gyms      start
# 1453  Non-Essential Businesses      start
# 1660            Food and Drink      start
# 1678                      Gyms      start
# 1942             Entertainment      start
# 1943             Entertainment      start
# 1969            Food and Drink      start
# 2426  Non-Essential Businesses      start
# 2441             Entertainment      start
# 3125            Food and Drink      start
# 3339                      Gyms      start
#
#                                                comments  \
# 501   Policy_Details: Stage 2 allows gradual reopeni...
# 628   Policy_Details: Currently open: Grocery stores...
# 768   Policy_Details: "Restaurants and bars must:\r\...
# 1198  Other measures and details for this policy inc...
# 1453  Policy_Details: " Essential businesses open\r\...
# 1660  Policy_Details: Currently open: Grocery stores...
# 1678  Other measures and details for this policy inc...
# 1942  Policy_Details: "Restaurants and bars must:\r\...
# 1943  Policy_Details: Currently open: Grocery stores...
# 1969  Policy_Details: " Essential businesses open\r\...
# 2426  Other measures and details for this policy inc...
# 2441  Policy_Details: " Essential businesses open\r\...
# 3125  Policy_Details: Stage 2 allows gradual reopeni...
# 3339  Other measures and details for this policy inc...
#
#                                                  source  total_phases
# 501   sip_submission_form: https://www.gov.ca.gov/wp...           NaN
# 628   sip_submission_form: https://govstatus.egov.co...           NaN
# 768   sip_submission_form: https://govstatus.egov.co...           NaN
# 1198                  BU COVID-19 State Policy Database           NaN
# 1453  sip_submission_form: https://www.governor.wa.g...           NaN
# 1660  sip_submission_form: https://govstatus.egov.co...           NaN
# 1678                  BU COVID-19 State Policy Database           NaN
# 1942  sip_submission_form: https://govstatus.egov.co...           NaN
# 1943  sip_submission_form: https://govstatus.egov.co...           NaN
# 1969  sip_submission_form: https://www.governor.wa.g...           NaN
# 2426                  BU COVID-19 State Policy Database           NaN
# 2441  sip_submission_form: https://www.governor.wa.g...           NaN
# 3125  sip_submission_form: https://www.gov.ca.gov/wp...           NaN
# 3339                  BU COVID-19 State Policy Database           NaN

# %%
# Create 'clean' Excel file with pertinent state emergency orders
state_restrictions.to_excel('Resources/Clean/Clean_EmergencyOrders.xlsx',
             sheet_name='State Emergency Orders')

# %%
# Generate a bar plot for state orders 
ugh_group = emergency_orders.groupby('date')
measures = pd.DataFrame(ugh_group['state_id'].count())

state_order_chart=measures.plot(kind='bar', title='State Emergency Orders', color='red')

plt.show()

# %%
state_order_type = emergency_orders.groupby(['date', 'policy_type'])['state_id'].count().unstack('policy_type').fillna(0)
state_order_type[['Gyms','Non-Essential Businesses', 'Entertainment']].plot(kind='bar', stacked=True)

# %%
#Preview
more_park_data.head()
# Out:
#                                               area  \
# 0     {'acres': '49,057.36', 'square_km': '198.5'}
# 1       {'acres': '8,256.67', 'square_km': '33.4'}
# 2     {'acres': '76,678.98', 'square_km': '310.3'}
# 3    {'acres': '242,755.94', 'square_km': '982.4'}
# 4  {'acres': '801,163.21', 'square_km': '3,242.2'}
#
#                                   coordinates date_established_readable  \
# 0    {'latitude': 44.35, 'longitude': -68.21}         February 26, 1919
# 1  {'latitude': -14.25, 'longitude': -170.68}          October 31, 1988
# 2   {'latitude': 38.68, 'longitude': -109.57}         November 12, 1971
# 3    {'latitude': 43.75, 'longitude': -102.5}         November 10, 1978
# 4   {'latitude': 29.25, 'longitude': -103.25}             June 12, 1944
#
#    date_established_unix                                        description  \
# 0            -1604599200  Covering most of Mount Desert Island and other...
# 1              594280800  The southernmost National Park is on three Sam...
# 2               58773600  This site features more than 2,000 natural san...
# 3              279525600  The Badlands are a collection of buttes, pinna...
# 4             -806439600  Named for the prominent bend in the Rio Grande...
#
#                                                image  \
# 0  {'url': 'acadia.jpg', 'attribution': 'PixelBay...
# 1  {'url': 'american-samoa.jpg', 'attribution': '...
# 2  {'url': 'arches.jpg', 'attribution': 'PixelBay...
# 3  {'url': 'badlands.jpg', 'attribution': 'PixelB...
# 4  {'url': 'big-bend.jpg', 'attribution': 'PixelB...
#
#                              nps_link  \
# 0  https://www.nps.gov/acad/index.htm
# 1  https://www.nps.gov/npsa/index.htm
# 2  https://www.nps.gov/arch/index.htm
# 3  https://www.nps.gov/badl/index.htm
# 4  https://www.nps.gov/bibe/index.htm
#
#                                               states           title  \
# 0          [{'id': 'state_maine', 'title': 'Maine'}]          Acadia
# 1  [{'id': 'state_american-samoa', 'title': 'Amer...  American Samoa
# 2            [{'id': 'state_utah', 'title': 'Utah'}]          Arches
# 3  [{'id': 'state_south-dakota', 'title': 'South ...        Badlands
# 4          [{'id': 'state_texas', 'title': 'Texas'}]        Big Bend
#
#                     id   visitors  world_heritage_site
# 0          park_acadia  3,303,393                False
# 1  park_american-samoa     28,892                False
# 2          park_arches  1,585,718                False
# 3        park_badlands    996,263                False
# 4        park_big-bend    388,290                False

# %%
#Grab info from necessary parks
parks_info = []
for index, row in more_park_data.iterrows():
    if row['title'] == "Redwood":
        park = row["title"], row["coordinates"]
        parks_info.append(park)
    elif row['title'] == "Yosemite":
        park = row["title"], row["coordinates"]
        parks_info.append(park)
    elif row['title'] == "Sequoia":
        park = row["title"], row["coordinates"]
        parks_info.append(park)
    elif row['title'] == "Death Valley":
        park = row["title"], row["coordinates"]
        parks_info.append(park)
    elif row['title'] == "Joshua Tree":
        park = row["title"], row["coordinates"]
        parks_info.append(park)
    elif row['title'] == "Channel Islands":
        park = row["title"], row["coordinates"]
        parks_info.append(park)
    elif row['title'] == "Lassen Volcanic":
        park = row["title"], row["coordinates"]
        parks_info.append(park)
    elif row['title'] == "Pinnacles":
        park = row["title"], row["coordinates"]
        parks_info.append(park)
    elif row['title'] == "Kings Canyon":
        park = row["title"], row["coordinates"]
        parks_info.append(park)
    elif row['title'] == "Biscayne":
        park = row["title"], row["coordinates"]
        parks_info.append(park)
    elif row['title'] == "Dry Tortugas":
        park = row["title"], row["coordinates"]
        parks_info.append(park)
    elif row['title'] == "Everglades":
        park = row["title"], row["coordinates"]
        parks_info.append(park)
        
#Create and format Dataframe
califl_df = pd.DataFrame(parks_info)
califlo_df = califl_df.rename(columns={0: "National Park", 1: "Coordinates"})

#Preview
califlo_df.head()
#Save as usable CSV
califlo_df.to_csv(r'/Users/laurelwilliamson/Desktop/GITHUB/group_project/ProjectOne/Resources/CaliFlo.csv', index = False)
# Out:
#      National Park                                Coordinates
# 0         Biscayne   {'latitude': 25.65, 'longitude': -80.08}
# 1  Channel Islands  {'latitude': 34.01, 'longitude': -119.42}
# 2     Death Valley  {'latitude': 36.24, 'longitude': -116.82}
# 3     Dry Tortugas   {'latitude': 24.63, 'longitude': -82.87}
# 4       Everglades   {'latitude': 25.32, 'longitude': -80.93}
